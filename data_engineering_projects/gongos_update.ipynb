# %%
import pandas as pd

# %%
# import current data
gongos_current = pd.read_excel("gongos_current.xlsx")
gongos_current.head(n = 5)
# Out:
#    Billing Account Number  Anytime Account Number           Club Name  \
# 0                    1000                    2664        Oakville, ON
# 1                    1001                    2166  Siloam Springs, AR
# 2                    1002                     435     Canyon Lake, TX
# 3                    1004                    2764       La Grande, OR
# 4                    1006                    2048      Alamogordo, NM
#
#                            Club Email       Club City Club State/Province  \
# 0       OakvilleON@anytimefitness.com        Oakville                  ON
# 1  SiloamSpringsAR@anytimefitness.com  Siloam Springs                  AR
# 2     CanyonLakeTX@anytimefitness.com     Canyon Lake                  TX
# 3       LaGrandeOR@anytimefitness.com       La Grande                  OR
# 4     AlamogordoNM@anytimefitness.com      Alamogordo                  NM
#
#              Owner               FBC Current Base Camp Report Month Base Camp  \
# 0        Rob Cucci       Sunny Pannu       Base Camp 6       Base Camp Canada
# 1       Tim Truman   Derrick Martini       Base Camp 6            Base Camp 2
# 2    Brian Portner   Patrick Lofboom       Base Camp 5            Base Camp 5
# 3  Nathan Fortlage  Stephanie Coffey       Base Camp 5            Base Camp 5
# 4   Douglas Graham    Rachele Jordan       Base Camp 3            Base Camp 3
#
#    ...           BOE  BOE Verified Date  Remit Amount     Dues  \
# 0  ...  17759.250000         2017-08-21  11497.440430  11457.0
# 1  ...  14000.000000         2017-11-01  10759.309570  10898.0
# 2  ...  11574.000000         2017-10-27  27318.939453  27782.0
# 3  ...  13883.110352                NaN  14394.230469  15201.0
# 4  ...  12300.000000         2017-07-06  43792.890625  31653.0
#
#   Dues Profit/Loss Draft Percent  PPV Revenue  Gross PT Income Problem%  \
# 0     -6302.250000        0.2093          NaN              NaN     1.16
# 1     -3102.000000        0.3767   382.450012              NaN     3.76
# 2     16208.000000        0.5326  2985.110107              NaN     4.40
# 3      1317.890015        0.2620  1494.349976            399.0     2.20
# 4     19353.000000        0.2060          NaN              NaN     5.15
#
#         Date
# 0 2018-01-20
# 1 2018-01-20
# 2 2018-01-20
# 3 2018-01-20
# 4 2018-01-20
#
# [5 rows x 67 columns]

# %%
# import new data
gongos_new = pd.read_excel("gongos_new.xlsx")
gongos_new.head(n = 5)
# Out:
#                     Mega Report              Unnamed: 1 Unnamed: 2  \
# 0  Report Generated: 2022-08-01                     NaN        NaN
# 1          Data From: June 2022                     NaN        NaN
# 2            No filters applied                     NaN        NaN
# 3                       Average                   Total        NaN
# 4        Billing Account Number  Anytime Account Number  Club Name
#
#    Unnamed: 3 Unnamed: 4           Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 0         NaN        NaN                  NaN        NaN        NaN
# 1         NaN        NaN                  NaN        NaN        NaN
# 2         NaN        NaN                  NaN        NaN        NaN
# 3         NaN        NaN                  NaN        NaN        NaN
# 4  Club Email  Club City  Club State/Province      Owner        FBC
#
#           Unnamed: 8              Unnamed: 9  ...        Unnamed: 52  \
# 0                NaN                     NaN  ...                NaN
# 1                NaN                     NaN  ...                NaN
# 2                NaN                     NaN  ...                NaN
# 3                NaN                     NaN  ...                NaN
# 4  Current Base Camp  Report Month Base Camp  ...  Gross Receivables
#
#   Unnamed: 53        Unnamed: 54   Unnamed: 55 Unnamed: 56       Unnamed: 57  \
# 0         NaN                NaN           NaN         NaN               NaN
# 1         NaN                NaN           NaN         NaN               NaN
# 2         NaN                NaN           NaN         NaN               NaN
# 3         NaN                NaN           NaN         NaN               NaN
# 4         BOE  BOE Verified Date  Remit Amount        Dues  Dues Profit/Loss
#
#      Unnamed: 58  Unnamed: 59      Unnamed: 60 Unnamed: 61
# 0            NaN          NaN              NaN         NaN
# 1            NaN          NaN              NaN         NaN
# 2            NaN          NaN              NaN         NaN
# 3            NaN          NaN              NaN         NaN
# 4  Draft Percent  PPV Revenue  Gross PT Income    Problem%
#
# [5 rows x 62 columns]

# %%
# promote proper headers
gongos_new.columns = gongos_new.iloc[4]
gongos_new.head(n = 10)
# Out:
# 4        Billing Account Number  Anytime Account Number           Club Name  \
# 0  Report Generated: 2022-08-01                     NaN                 NaN
# 1          Data From: June 2022                     NaN                 NaN
# 2            No filters applied                     NaN                 NaN
# 3                       Average                   Total                 NaN
# 4        Billing Account Number  Anytime Account Number           Club Name
# 5                           NaN                     NaN                 NaN
# 6                           NaN                     NaN                 NaN
# 7                          1001                    2166  Siloam Springs, AR
# 8                          1002                     435     Canyon Lake, TX
# 9                          1003                    4440  Cliffside Park, NJ
#
# 4                          Club Email       Club City  Club State/Province  \
# 0                                 NaN             NaN                  NaN
# 1                                 NaN             NaN                  NaN
# 2                                 NaN             NaN                  NaN
# 3                                 NaN             NaN                  NaN
# 4                          Club Email       Club City  Club State/Province
# 5                                 NaN             NaN                  NaN
# 6                                 NaN             NaN                  NaN
# 7  SiloamSpringsAR@anytimefitness.com  Siloam Springs                   AR
# 8     CanyonLakeTX@anytimefitness.com     Canyon Lake                   TX
# 9  CliffsideParkNJ@anytimefitness.com  Cliffside Park                   NJ
#
# 4             Owner             FBC  Current Base Camp  \
# 0               NaN             NaN                NaN
# 1               NaN             NaN                NaN
# 2               NaN             NaN                NaN
# 3               NaN             NaN                NaN
# 4             Owner             FBC  Current Base Camp
# 5               NaN             NaN                NaN
# 6               NaN             NaN                NaN
# 7        Tim Truman  Trevor Theriot        Base Camp 6
# 8     Brian Portner      Jim Dalton        Base Camp 5
# 9  Michael Orecchio  Sarah Jo Emter        Base Camp 3
#
# 4  Report Month Base Camp  ...  Gross Receivables             BOE  \
# 0                     NaN  ...                NaN             NaN
# 1                     NaN  ...                NaN             NaN
# 2                     NaN  ...                NaN             NaN
# 3                     NaN  ...                NaN             NaN
# 4  Report Month Base Camp  ...  Gross Receivables             BOE
# 5                     NaN  ...        $142,513.00      $19,627.00
# 6                     NaN  ...    $371,817,613.00  $49,186,425.00
# 7             Base Camp 6  ...       23555.070312     9159.160156
# 8             Base Camp 5  ...         241876.625           11574
# 9             Base Camp 3  ...           317049.5           55000
#
# 4  BOE Verified Date    Remit Amount            Dues  Dues Profit/Loss  \
# 0                NaN             NaN             NaN               NaN
# 1                NaN             NaN             NaN               NaN
# 2                NaN             NaN             NaN               NaN
# 3                NaN             NaN             NaN               NaN
# 4  BOE Verified Date    Remit Amount            Dues  Dues Profit/Loss
# 5                NaN      $24,478.00      $23,815.00         $4,253.00
# 6                NaN  $63,861,830.00  $61,753,201.00    $10,589,289.00
# 7         2019-11-07    10837.339844    11456.370117       2297.209961
# 8         2019-12-13    33821.539062    33714.378906      22140.380859
# 9         2020-11-06    76049.523438    76078.679688      21078.679688
#
# 4  Draft Percent  PPV Revenue  Gross PT Income  Problem%
# 0            NaN          NaN              NaN       NaN
# 1            NaN          NaN              NaN       NaN
# 2            NaN          NaN              NaN       NaN
# 3            NaN          NaN              NaN       NaN
# 4  Draft Percent  PPV Revenue  Gross PT Income  Problem%
# 5         38.00%            -        $6,838.00       NaN
# 6     99,799.00%        $0.00   $12,178,804.00       NaN
# 7           0.17          NaN              NaN      0.04
# 8            0.7          NaN      1782.959961      0.03
# 9           0.04          NaN     28785.820312      0.06
#
# [10 rows x 62 columns]

# %%
# remove top rows
gongos_new.drop(axis = 0, index = [0, 1, 2, 3, 4, 5, 6], inplace = True)
gongos_new.head()
# Out:
# 4  Billing Account Number Anytime Account Number           Club Name  \
# 7                    1001                   2166  Siloam Springs, AR
# 8                    1002                    435     Canyon Lake, TX
# 9                    1003                   4440  Cliffside Park, NJ
# 10                   1004                   2764       La Grande, OR
# 11                   1006                   2048      Alamogordo, NM
#
# 4                           Club Email       Club City Club State/Province  \
# 7   SiloamSpringsAR@anytimefitness.com  Siloam Springs                  AR
# 8      CanyonLakeTX@anytimefitness.com     Canyon Lake                  TX
# 9   CliffsideParkNJ@anytimefitness.com  Cliffside Park                  NJ
# 10       LaGrandeOR@anytimefitness.com       La Grande                  OR
# 11     AlamogordoNM@anytimefitness.com      Alamogordo                  NM
#
# 4              Owner             FBC Current Base Camp Report Month Base Camp  \
# 7         Tim Truman  Trevor Theriot       Base Camp 6            Base Camp 6
# 8      Brian Portner      Jim Dalton       Base Camp 5            Base Camp 5
# 9   Michael Orecchio  Sarah Jo Emter       Base Camp 3            Base Camp 3
# 10   Nathan Fortlage  Heather George       Base Camp 5            Base Camp 5
# 11    Douglas Graham   Jamie Mueller       Base Camp 3            Base Camp 3
#
# 4   ... Gross Receivables          BOE BOE Verified Date  Remit Amount  \
# 7   ...      23555.070312  9159.160156        2019-11-07  10837.339844
# 8   ...        241876.625        11574        2019-12-13  33821.539062
# 9   ...          317049.5        55000        2020-11-06  76049.523438
# 10  ...     103202.257812        13000        2021-10-27  24278.359375
# 11  ...        187632.375        18600        2021-06-16       22593.5
#
# 4           Dues Dues Profit/Loss Draft Percent PPV Revenue Gross PT Income  \
# 7   11456.370117      2297.209961          0.17         NaN             NaN
# 8   33714.378906     22140.380859           0.7         NaN     1782.959961
# 9   76078.679688     21078.679688          0.04         NaN    28785.820312
# 10  24340.349609     11340.349609           0.5         NaN            3220
# 11  21945.400391      3345.399902          0.11         NaN             NaN
#
# 4  Problem%
# 7      0.04
# 8      0.03
# 9      0.06
# 10     0.04
# 11     0.05
#
# [5 rows x 62 columns]

# %%
# rename columns
gongos_new.rename(inplace = True, columns = {
    'Monthly Attrition': 'Monthly Attrition Base',
    'Rolling 12-Month Attrition': 'Rolling 12-Month Attrition Base'
})

# add new columns
gongos_new.insert(36, 'Monthly Attrition Factor', value = '') # replace blank with value when needed
gongos_new.insert(37, 'Monthly Attrition', value = ' ')
gongos_new.insert(39, 'Rolling 12-Month Attrition Factor', value = '') # replace blanks with value when needed
gongos_new.insert(40, 'Rolling 12-Month Attrition', value = ' ')
gongos_new.insert(66, 'Date', value = '06/01/2022') # replace with new date

# list all columns
list(enumerate(gongos_new.columns))
# Out:
# [(0, 'Billing Account Number'),
#  (1, 'Anytime Account Number'),
#  (2, 'Club Name'),
#  (3, 'Club Email'),
#  (4, 'Club City'),
#  (5, 'Club State/Province'),
#  (6, 'Owner'),
#  (7, 'FBC'),
#  (8, 'Current Base Camp'),
#  (9, 'Report Month Base Camp'),
#  (10, 'Months Open'),
#  (11, 'Square Footage'),
#  (12, 'Club Purple'),
#  (13, 'Club Platinum'),
#  (14, 'Census Region'),
#  (15, 'FBC Region'),
#  (16, 'Market Class'),
#  (17, 'Store Class'),
#  (18, 'DMA'),
#  (19, '5-mile Pop.'),
#  (20, 'Live Programming'),
#  (21, 'KP Softworks'),
#  (22, 'KP Softworks Start Date'),
#  (23, 'Flexible Billing'),
#  (24, 'Active CMS'),
#  (25, 'FA Expiration'),
#  (26, 'Base Member Count'),
#  (27, 'PPV Count'),
#  (28, 'Total Members'),
#  (29, 'PIF Percent'),
#  (30, 'Contract Count (in-agreement)'),
#  (31, 'Average Member Value'),
#  (32, 'Average Mbr Contract Value'),
#  (33, 'Average Member Tenure (months)'),
#  (34, 'Average Member Term (months)'),
#  (35, 'Monthly Attrition Base'),
#  (36, 'Monthly Attrition Factor'),
#  (37, 'Monthly Attrition'),
#  (38, 'Rolling 12-Month Attrition Base'),
#  (39, 'Rolling 12-Month Attrition Factor'),
#  (40, 'Rolling 12-Month Attrition'),
#  (41, 'Exited Agreements'),
#  (42, 'New Agreement'),
#  (43, 'Presale Count'),
#  (44, 'Presale Count from ABC'),
#  (45, 'Prospect Count'),
#  (46, 'Appointment (Appt) Scheduled'),
#  (47, 'Appointment (Appt) Show'),
#  (48, 'Unscheduled Visits'),
#  (49, 'Total Tours'),
#  (50, 'New Membership Agreements'),
#  (51, 'Fitness Consultation (FC) Scheduled'),
#  (52, 'Fitness Consultation (FC) Show'),
#  (53, 'New PT Agreements'),
#  (54, 'PLEASE Score'),
#  (55, 'Total Receivables Collected'),
#  (56, 'Gross Receivables'),
#  (57, 'BOE'),
#  (58, 'BOE Verified Date'),
#  (59, 'Remit Amount'),
#  (60, 'Dues'),
#  (61, 'Dues Profit/Loss'),
#  (62, 'Draft Percent'),
#  (63, 'PPV Revenue'),
#  (64, 'Gross PT Income'),
#  (65, 'Problem%'),
#  (66, 'Date')]

# %%
# perform transformations on attrition columns where existing values are all 0
# gongos_new.iloc[:, 35].replace(to_replace = 0, value = '', inplace = True)
# gongos_new.iloc[:, 38].replace(to_replace = 0, value = '', inplace = True)

# perform transformations on attrition columns where existing values are not 0
gongos_new.iloc[:, 36].replace(to_replace = '', value = 1, inplace = True)
gongos_new.iloc[:, 39].replace(to_replace = '', value = 1, inplace = True)
gongos_new['Monthly Attrition'] = gongos_new['Monthly Attrition Base'] * gongos_new['Monthly Attrition Factor']
gongos_new['Rolling 12-Month Attrition'] = gongos_new['Rolling 12-Month Attrition Base'] * gongos_new['Rolling 12-Month Attrition Factor']

# %%
# concat new data to existing data
frames = [gongos_current, gongos_new]
gongos_final = pd.concat(frames)
gongos_final.head()
# Out:
#   Billing Account Number Anytime Account Number           Club Name  \
# 0                   1000                   2664        Oakville, ON
# 1                   1001                   2166  Siloam Springs, AR
# 2                   1002                    435     Canyon Lake, TX
# 3                   1004                   2764       La Grande, OR
# 4                   1006                   2048      Alamogordo, NM
#
#                            Club Email       Club City Club State/Province  \
# 0       OakvilleON@anytimefitness.com        Oakville                  ON
# 1  SiloamSpringsAR@anytimefitness.com  Siloam Springs                  AR
# 2     CanyonLakeTX@anytimefitness.com     Canyon Lake                  TX
# 3       LaGrandeOR@anytimefitness.com       La Grande                  OR
# 4     AlamogordoNM@anytimefitness.com      Alamogordo                  NM
#
#              Owner               FBC Current Base Camp Report Month Base Camp  \
# 0        Rob Cucci       Sunny Pannu       Base Camp 6       Base Camp Canada
# 1       Tim Truman   Derrick Martini       Base Camp 6            Base Camp 2
# 2    Brian Portner   Patrick Lofboom       Base Camp 5            Base Camp 5
# 3  Nathan Fortlage  Stephanie Coffey       Base Camp 5            Base Camp 5
# 4   Douglas Graham    Rachele Jordan       Base Camp 3            Base Camp 3
#
#    ...           BOE BOE Verified Date  Remit Amount     Dues  \
# 0  ...      17759.25        2017-08-21   11497.44043  11457.0
# 1  ...       14000.0        2017-11-01   10759.30957  10898.0
# 2  ...       11574.0        2017-10-27  27318.939453  27782.0
# 3  ...  13883.110352               NaN  14394.230469  15201.0
# 4  ...       12300.0        2017-07-06  43792.890625  31653.0
#
#   Dues Profit/Loss Draft Percent  PPV Revenue Gross PT Income Problem%  \
# 0         -6302.25        0.2093          NaN             NaN     1.16
# 1          -3102.0        0.3767   382.450012             NaN     3.76
# 2          16208.0        0.5326  2985.110107             NaN      4.4
# 3      1317.890015         0.262  1494.349976           399.0      2.2
# 4          19353.0         0.206          NaN             NaN     5.15
#
#                   Date
# 0  2018-01-20 00:00:00
# 1  2018-01-20 00:00:00
# 2  2018-01-20 00:00:00
# 3  2018-01-20 00:00:00
# 4  2018-01-20 00:00:00
#
# [5 rows x 67 columns]

# %%
# save final dataframe
gongos_final.to_excel('gongos_final.xlsx', index = False)
